# %% [markdown]
# # Soccer AI Analysis
#
# Load predictions and evaluate performance.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

conn = sqlite3.connect('../data/betting.db')
predictions = pd.read_sql_query('SELECT * FROM predictions', conn)
results = pd.read_sql_query('SELECT * FROM fixture_results', conn)

merged = pd.merge(predictions, results, on='fixture_id', how='left')
merged.head()
